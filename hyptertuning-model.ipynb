# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("churn.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(12,10))

# %%
sns.countplot(x="Exited",data=df)
plt.title("Distribution of Churn")
# Out:
# Text(0.5, 1.0, 'Distribution of Churn')

# %%
sns.histplot(data=df,x="Age",kde=True) #kde is kernel density estimation which is a way to estimate the probability density function of a random variable
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.scatterplot(data=df,x="CreditScore",y="Age",hue="Exited")
plt.title("Credit Score vs Age")
# Out:
# Text(0.5, 1.0, 'Credit Score vs Age')

# %%
sns.boxplot(x="Exited",y="Balance",data=df)
plt.title("Balance Distributed by Churn")
# Out:
# Text(0.5, 1.0, 'Balance Distributed by Churn')

# %%
sns.boxplot(x="Exited",y="CreditScore",data=df)
plt.title("Credit Score Distributed by Churn")
# Out:
# Text(0.5, 1.0, 'Credit Score Distributed by Churn')

# %%
features = df.drop('Exited',axis=1)
features
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
target = df['Exited']

# %%
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
features = features.drop(["RowNumber","CustomerId","Surname"],axis=1)

# %%
features
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
features = features.dropna()
features
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
features = pd.get_dummies(features,columns=["Geography","Gender"])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 0.35649971, -0.6557859 ,  0.34567966, ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [-0.20389777,  0.29493847, -0.3483691 , ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [-0.96147213, -1.41636539, -0.69539349, ...,  1.73494238,
#         -0.91324755,  0.91324755],
#        ...,
#        [ 0.86500853, -0.08535128, -1.38944225, ..., -0.57638802,
#          1.09499335, -1.09499335],
#        [ 0.15932282,  0.3900109 ,  1.03972843, ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [ 0.47065475,  1.15059039, -1.38944225, ..., -0.57638802,
#         -0.91324755,  0.91324755]])

# %%
X_train[0]
# Out:
# array([ 0.35649971, -0.6557859 ,  0.34567966, -1.21847056,  0.80843615,
#         0.64920267,  0.97481699,  1.36766974,  1.00150113, -0.57946723,
#        -0.57638802, -0.91324755,  0.91324755])

# %%
X_train[1]
# Out:
# array([-0.20389777,  0.29493847, -0.3483691 ,  0.69683765,  0.80843615,
#         0.64920267,  0.97481699,  1.6612541 , -0.99850112,  1.72572313,
#        -0.57638802, -0.91324755,  0.91324755])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

import pickle


import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
lr_model = LogisticRegression(random_state=42)

# %%
lr_model.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)

# %%
lr_accuracy =accuracy_score(y_test,lr_predictions)

# %%
lr_accuracy
# Out:
# 0.811

# %%
def evaluate_and_save_model(model,X_train,X_test,y_train,y_test,filename):
  model.fit(X_train,y_train)
  y_pred = model.predict(X_test)
  accuracy = accuracy_score(y_test,y_pred)
  print(f"{model.__class__.__name__} Acccuracy: {accuracy:.4f}")
  print(f"\nClassification Report:\n{classification_report(y_test,y_pred)}")
  print("-------")

  with open(filename,"wb") as file:
    pickle.dump(model,file)

  print(f"Model saved as {filename}")

# %%
xgb_model = xgb.XGBClassifier(random_state=42,objective='binary:logistic', 
    n_estimators=100,
    eval_metric='logloss')
evaluate_and_save_model(xgb_model,X_train,X_test,y_train,y_test,"xgb_model.pkl")


dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model,X_train,X_test,y_train,y_test,"dt_model.pkl")

rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model,X_train,X_test,y_train,y_test,"rf_model.pkl")

nb_model = GaussianNB()
evaluate_and_save_model(nb_model,X_train,X_test,y_train,y_test,"nb_model.pkl")

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model,X_train,X_test,y_train,y_test,"knn_model.pkl")

svm_model = SVC(probability=True,random_state=42)
evaluate_and_save_model(svm_model,X_train,X_test,y_train,y_test,"svm_model.pkl")
# Out:
# XGBClassifier Acccuracy: 0.7455
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.83      1607
#            1       0.39      0.54      0.45       393
#
#     accuracy                           0.75      2000
#    macro avg       0.63      0.67      0.64      2000
# weighted avg       0.78      0.75      0.76      2000
#
# -------
# Model saved as xgb_model.pkl
# DecisionTreeClassifier Acccuracy: 0.7850
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1607
#            1       0.46      0.51      0.48       393
#
#     accuracy                           0.79      2000
#    macro avg       0.67      0.68      0.67      2000
# weighted avg       0.80      0.79      0.79      2000
#
# -------
# Model saved as dt_model.pkl
# RandomForestClassifier Acccuracy: 0.8670
#
# Classification Report:
# ...

# %%
feature_importance = xgb_model.feature_importances_
feature_names = features.columns

# %%
feature_importance
# Out:
# array([0.03500515, 0.10955006, 0.03005428, 0.05278618, 0.32388848,
#        0.03194036, 0.16414645, 0.03265523, 0.04646329, 0.09137334,
#        0.0368547 , 0.04528258, 0.        ], dtype=float32)

# %%
feature_names
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_France',
#        'Geography_Germany', 'Geography_Spain', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
feature_importances_df = pd.DataFrame({
    'feature':feature_names,
    'importance':feature_importance
})

# %%
feature_importances_df
# Out:
#               feature  importance
# 0         CreditScore    0.035005
# 1                 Age    0.109550
# 2              Tenure    0.030054
# 3             Balance    0.052786
# 4       NumOfProducts    0.323888
# 5           HasCrCard    0.031940
# 6      IsActiveMember    0.164146
# 7     EstimatedSalary    0.032655
# 8    Geography_France    0.046463
# 9   Geography_Germany    0.091373
# 10    Geography_Spain    0.036855
# 11      Gender_Female    0.045283
# 12        Gender_Male    0.000000

# %%
feature_importances_df = feature_importances_df.sort_values('importance',ascending=False)

# %%
feature_importances_df
# Out:
#               feature  importance
# 4       NumOfProducts    0.323888
# 6      IsActiveMember    0.164146
# 1                 Age    0.109550
# 9   Geography_Germany    0.091373
# 3             Balance    0.052786
# 8    Geography_France    0.046463
# 11      Gender_Female    0.045283
# 10    Geography_Spain    0.036855
# 0         CreditScore    0.035005
# 7     EstimatedSalary    0.032655
# 5           HasCrCard    0.031940
# 2              Tenure    0.030054
# 12        Gender_Male    0.000000

# %%
plt.figure(figsize=(10,6))
plt.bar(feature_importances_df['feature'],feature_importances_df['importance'])
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel('Importance')
plt.tight_layout()
plt.show()

# %%
features['CLV'] = df['Balance']* df['EstimatedSalary'] / 100000

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['AgeGroup'] = pd.cut(df['Age'],bins=[0,30,45,60,100],labels=['Young',"MiddleAge","Senior","Elderly"])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['TenureAgeRatio'] = df['Tenure']/df['Age']

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features = pd.get_dummies(features,drop_first=True)

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
#Accuracy improved but recall decresed
#SMOTE
from imblearn.over_sampling import SMOTE


xgboost_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgboost_model,X_train,X_test,y_train,y_test,"xgboost-featureEngineered_model.pkl")
# Out:
# XGBClassifier Acccuracy: 0.8540
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.67      0.50      0.58       393
#
#     accuracy                           0.85      2000
#    macro avg       0.78      0.72      0.74      2000
# weighted avg       0.84      0.85      0.85      2000
#
# -------
# Model saved as xgboost-featureEngineered_model.pkl

# %%
smote = SMOTE(random_state=42)
X_resample , y_resample  = smote.fit_resample(X_train,y_train)

# %%
evaluate_and_save_model(xgboost_model,X_resample,X_test,y_resample,y_test,"xgboost-SMOTE.pkl")
# Out:
# XGBClassifier Acccuracy: 0.8545
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1607
#            1       0.65      0.55      0.60       393
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.74      0.75      2000
# weighted avg       0.85      0.85      0.85      2000
#
# -------
# Model saved as xgboost-SMOTE.pkl

# %%
#Overall the recall increased
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(
    estimators=[
        ('xgboost',xgb.XGBClassifier(random_state=42)),
        ('random_forest',RandomForestClassifier(random_state=42)),
        ('logistic_regression',LogisticRegression(random_state=42)),
        ('knn',KNeighborsClassifier()),
        ('svm',SVC(probability=True,random_state=42)),
        ('naive_bayes',GaussianNB()),
        ('decision_tree',DecisionTreeClassifier(random_state=42))
    ],
    voting='soft'

)

# %%
evaluate_and_save_model(voting_clf,X_resample,X_test,y_resample,y_test,"voting_classifier.pkl")
# Out:
# /Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier Acccuracy: 0.8390
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      1607
#            1       0.59      0.57      0.58       393
#
#     accuracy                           0.84      2000
#    macro avg       0.75      0.74      0.74      2000
# weighted avg       0.84      0.84      0.84      2000
#
# ...

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
xgboost_model = xgb.XGBClassifier(random_state=42)
xgboost_model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
# ...

# %%
# X = df[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Geography_France', 'Geography_Germany', 'Geography_Spain', 'Gender_Male', 'Gender_Female']]
y = df['Exited']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9069          619   32       4  175406.13              2          1
# 2603          643   34       7  160426.07              1          0
# 7738          561   33       6       0.00              2          0
# 1579          618   41       8   37702.79              1          1
# 5058          714   37       9  148466.93              2          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
param_grid = {
    # Hyperparameters for XGBoost
    'xgboost__n_estimators': [50, 100, 200],
    'xgboost__learning_rate': [0.01, 0.1, 0.2],
    'xgboost__max_depth': [3, 5, 7],
    'xgboost__subsample': [0.5, 0.7, 1],
    'xgboost__colsample_bytree': [0.5, 0.7, 1],
    'xgboost__gamma': [0, 0.1, 0.2],
    'xgboost__reg_alpha': [0, 0.1, 0.2],
    'xgboost__reg_lambda': [0, 0.1, 0.2],
    'xgboost__min_child_weight': [0, 1, 2],
    'xgboost__scale_pos_weight': [0, 1, 2],
    
    # Hyperparameters for Random Forest
    'random_forest__n_estimators': [50, 100, 200],
    'random_forest__max_depth': [5, 10, 15],
    # 'random_forest__min_samples_split': [2, 5, 10],
    
    # Hyperparameters for Logistic Regression


    'logistic_regression__C': [0.1, 1.0, 10.0],
    'logistic_regression__solver': ['lbfgs', 'liblinear']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=voting_clf, param_grid=param_grid, cv=5, verbose=2, n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get best parameters
best_params = grid_search.best_params_
# st.write("Best Parameters:", best_params)

# Get grid search results
results = pd.DataFrame(grid_search.cv_results_)
# Out:
# Fitting 5 folds for each of 3188646 candidates, totalling 15943230 fits
# /Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
results.
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.387103      0.017477         0.016342        0.005518
# 1        0.397394      0.021240         0.014265        0.002766
# 2        0.436934      0.012626         0.018984        0.002106
# 3        0.691994      0.064047         0.025588        0.002922
# 4        0.641002      0.014854         0.021341        0.004229
# 5        0.829244      0.082249         0.034651        0.011276
# 6        1.593828      0.179531         0.044890        0.021033
# 7        1.857939      0.453581         0.065832        0.024150
# 8        1.573145      0.045405         0.046937        0.004935
# 9        0.553111      0.135648         0.021604        0.010380
# 10       0.441901      0.037883         0.013747        0.001588
# 11       0.473457      0.023032         0.017036        0.003714
# 12       0.833676      0.100714         0.027205        0.007419
# ...

# %%
def save_model(model,filename):
 
    with open(filename,"wb") as file:
      pickle.dump(model,file)

    print(f"Model saved as {filename}")

# %%
save_model(results,"gridSearch.pkl")
# Out:
# Model saved as gridSearch.pkl

# %%
evaluate_and_save_model(grid_search.best_estimator_,X_train,X_test,y_train,y_test,"gridSearch-eval.pkl")
# Out:
# VotingClassifier Acccuracy: 0.8650
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2416
#            1       0.83      0.39      0.53       584
#
#     accuracy                           0.86      3000
#    macro avg       0.85      0.68      0.72      3000
# weighted avg       0.86      0.86      0.84      3000
#
# -------
# Model saved as gridSearch-eval.pkl
# /Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Define hyperparameter distributions
from scipy.stats import randint, uniform
import numpy as np
param_distributions = {
   # XGBoost hyperparameters
    'xgboost__n_estimators': randint(50, 200),
    'xgboost__learning_rate': uniform(0.01, 0.3),
    'xgboost__max_depth': randint(3, 10),
    
    # Random Forest hyperparameters
    'random_forest__n_estimators': randint(100, 200),
    'random_forest__max_depth': randint(5, 15),
    
    # Logistic Regression hyperparameters
    'logistic_regression__C': np.logspace(-3, 3, 7),
    'logistic_regression__solver': ['lbfgs', 'liblinear'],
    
    # SVM hyperparameters
    'svc__C': np.logspace(-3, 3, 7),  # Regularization parameter
    'svc__kernel': ['linear', 'rbf'],  # Kernel type
    
    # KNN hyperparameters
    'knn__n_neighbors': randint(3, 10),  # Number of neighbors
    'knn__weights': ['uniform', 'distance']  # Weight function
    
}

# %%
from sklearn.model_selection import RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=voting_clf, 
    param_distributions=param_distributions, 
    n_iter=20,  # Number of parameter combinations to try
    cv=5,  # 5-fold cross-validation
    verbose=2,  # For detailed output during tuning
    n_jobs=-1,  # Use all available cores
    random_state=42
)

# %%
# Fit the RandomizedSearchCV model
random_search.fit(X_train, y_train)

# Get the best parameters and estimator
best_params = random_search.best_params_

best_estimator = random_search.best_estimator_

# st.write("Best Parameters: ", best_params)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
# ...

# %%
best_params
# Out:
# {'logistic_regression__C': np.float64(10.0),
#  'logistic_regression__solver': 'lbfgs',
#  'random_forest__max_depth': 9,
#  'random_forest__n_estimators': 156,
#  'xgboost__colsample_bytree': 0.5,
#  'xgboost__gamma': 0,
#  'xgboost__learning_rate': 0.2,
#  'xgboost__max_depth': 4,
#  'xgboost__min_child_weight': 2,
#  'xgboost__n_estimators': 124,
#  'xgboost__reg_alpha': 0.2,
#  'xgboost__reg_lambda': 0,
#  'xgboost__scale_pos_weight': 2,
#  'xgboost__subsample': 0.7}

# %%
best_estimator.get_params()
# Out:
# {'estimators': [('xgboost',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, device=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=0.2, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=7, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  multi_strategy=None, n_estimators=149, n_jobs=None,
#                  num_parallel_tree=None, random_state=42, ...)),
#   ('random_forest',
#    RandomForestClassifier(max_depth=9, n_estimators=124, random_state=42)),
#   ('logistic_regression',
# ...

# %%
y_pred = best_estimator.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8683333333333333

# %%
evaluate_and_save_model(best_estimator,X_train,X_test,y_train,y_test,"randomSearch-eval.pkl")
# Out:
# VotingClassifier Acccuracy: 0.8683
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2416
#            1       0.82      0.41      0.55       584
#
#     accuracy                           0.87      3000
#    macro avg       0.85      0.69      0.74      3000
# weighted avg       0.86      0.87      0.85      3000
#
# -------
# Model saved as randomSearch-eval.pkl
# /Users/amanpurohit/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
best_estimator.get_params()
y_pred = best_estimator.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)


# accuracy = accuracy_score(y_test,y_pred)
# print(f"{xgb_Hyper.__class__.__name__} Acccuracy: {accuracy:.4f}")
# print(f"\nClassification Report:\n{classification_report(y_test,y_pred)}")
# print("-------")
# best_estimator.get_params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/utils/_available_if.py:29, in _AvailableIfDescriptor._check(self, obj, owner)
#      28 try:
# ---> 29     check_result = self.check(obj)
#      30 except Exception as e:
#
# File ~/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:822, in BaseSVC._check_proba(self)
#     821 if not self.probability:
# --> 822     raise AttributeError(
#     823         "predict_proba is not available when probability=False"
#     824     )
#     825 if self._impl not in ("c_svc", "nu_svc"):
#
# AttributeError: predict_proba is not available when probability=False
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
evaluate_and_save_model(random_search,X_train,X_test,y_train,y_test,"xgb_Hyper-eval.pkl")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END logistic_regression__C=100.0, logistic_regression__solver=liblinear, random_forest__max_depth=6, random_forest__n_estimators=87, xgboost__colsample_bytree=0.7, xgboost__gamma=0, xgboost__learning_rate=0.01, xgboost__max_depth=6, xgboost__min_child_weight=1, xgboost__n_estimators=71, xgboost__reg_alpha=0, xgboost__reg_lambda=0, xgboost__scale_pos_weight=0, xgboost__subsample=1; total time=   0.5s
# [CV] END logistic_regression__C=100.0, logistic_regression__solver=liblinear, random_forest__max_depth=6, random_forest__n_estimators=87, xgboost__colsample_bytree=0.7, xgboost__gamma=0, xgboost__learning_rate=0.01, xgboost__max_depth=6, xgboost__min_child_weight=1, xgboost__n_estimators=71, xgboost__reg_alpha=0, xgboost__reg_lambda=0, xgboost__scale_pos_weight=0, xgboost__subsample=1; total time=   0.5s
# ...

# %%
y_pred = best_estimator.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy
classification_report(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/utils/_available_if.py:29, in _AvailableIfDescriptor._check(self, obj, owner)
#      28 try:
# ---> 29     check_result = self.check(obj)
#      30 except Exception as e:
#
# File ~/Desktop/Accelerator/Churn/ChurnPredictionModel/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:822, in BaseSVC._check_proba(self)
#     821 if not self.probability:
# --> 822     raise AttributeError(
#     823         "predict_proba is not available when probability=False"
#     824     )
#     825 if self._impl not in ("c_svc", "nu_svc"):
#
# AttributeError: predict_proba is not available when probability=False
#
# The above exception was the direct cause of the following exception:
#
# ...
