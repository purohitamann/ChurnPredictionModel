# %%
import requests

url = "https://churnpredictionmodel.onrender.com/predict"
customer_data = {
    "CreditScore": 600,
    "Geography": "France",
    "Gender": "Male",
    "Age": 40,
    "Tenure": 3,
    "Balance": 60000,
    "NumOfProducts": 2,
    "HasCrCard": True,
    "IsActiveMember": True,
    "EstimatedSalary": 60000
}

response = requests.post(url, json=customer_data)
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Error: 403 <html><title>403: Forbidden</title><body>403: Forbidden</body></html>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming the response is a dictionary and we add the "Exited" status manually for demo purposes
response_data = {
    "CreditScore": 200,
    "Geography": "France",
    "Gender": "Male",
    "Age": 40,
    "Tenure": 3,
    "Balance": 60000,
    "NumOfProducts": 2,
    "HasCrCard": 1,
    "IsActiveMember": 1,
    "EstimatedSalary": 6,
    "Exited": 1  # Add Exited status manually for testing if needed
}

# Convert the response data to a DataFrame
df = pd.DataFrame([response_data])

# Check if "Exited" is in the DataFrame
print(df.columns)

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.countplot(x="Exited", data=df)
plt.title("Balance Distributed by Churn")
plt.show()
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')
